# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
sayi = int(input("bir sayı giriniz:"))
if sayi > 0:
    print(sayi,"pozitif bir sayıdır.")
elif sayi < 0:
    print(sayi,"negatif bir sayıdır.")
else:
    print("bu sayı 0'dır.")
# Out:
# 8 pozitif bir sayıdır.

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
sayi = int(input("bir sayı giriniz:"))
bolenSayiToplami = 0 
for x in range(1,sayi):
   
    if sayi % x == 0:
        bolenSayiToplami += x 
    
if  sayi == bolenSayiToplami:
        print(f"{sayi} mükemmel bir sayıdır.")
else:
        print(f"{sayi} mükemmel bir sayı değildir.")
# Out:
# 35 mükemmel bir sayı değildir.

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
sayi = (input("bir sayı giriniz:"))
toplam = 0
sayi = str(sayi)
basamakSayisi = len(sayi)
for  a in sayi:
    sayi = int(sayi)
    toplam += (int(a))**(basamakSayisi)
if toplam == sayi:
        print(f"{sayi} Armstrong bir sayıdır.")
else :
        print(f"{sayi} Armstrong bir sayı değildir.")
# Out:
# 1634 Armstrong bir sayıdır.

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
for f in range(1,11):
    print("-------------------------------")
    for z in range(1,11):
       
        print(f"{f}*{z}={f*z}")
# Out:
# -------------------------------
# 1*1=1
# 1*2=2
# 1*3=3
# 1*4=4
# 1*5=5
# 1*6=6
# 1*7=7
# 1*8=8
# 1*9=9
# 1*10=10
# -------------------------------
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20
# -------------------------------
# 3*1=3
# 3*2=6
# 3*3=9
# 3*4=12
# 3*5=15
# 3*6=18
# 3*7=21
# 3*8=24
# 3*9=27
# 3*10=30
# -------------------------------
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 4*10=40
# -------------------------------
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
# -------------------------------
# 6*1=6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 6*7=42
# 6*8=48
# 6*9=54
# 6*10=60
# -------------------------------
# 7*1=7
# 7*2=14
# 7*3=21
# 7*4=28
# 7*5=35
# 7*6=42
# 7*7=49
# 7*8=56
# 7*9=63
# 7*10=70
# -------------------------------
# 8*1=8
# 8*2=16
# 8*3=24
# 8*4=32
# 8*5=40
# 8*6=48
# 8*7=56
# 8*8=64
# 8*9=72
# 8*10=80
# -------------------------------
# 9*1=9
# 9*2=18
# 9*3=27
# 9*4=36
# 9*5=45
# 9*6=54
# 9*7=63
# 9*8=72
# 9*9=81
# 9*10=90
# -------------------------------
# 10*1=10
# 10*2=20
# 10*3=30
# 10*4=40
# 10*5=50
# 10*6=60
# 10*7=70
# 10*8=80
# 10*9=90
# 10*10=100

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
# aldığım ürünlerin fiyatı: 16,17 ve 18
toplam = 0
while True:
    fiyat = input("çıkmak için q tuşuna basınız.")

    if fiyat == "q":
        print(f"tutarınız:{toplam}")
        break

    else:
        toplam += int(fiyat)
# Out:
# tutarınız:48

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
for z in range(1,100):
    if z % 3 != 0:
        continue
    print(z)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
for q in range(1,100):
    if q % 15 == 0:
        print("YetGen")
       
    elif q % 5 == 0:
        print("Gen")
        
    elif q % 3 == 0:
        print("Yet")
    else:
        print(q)
# Out:
# 1
# 2
# Yet
# 4
# Gen
# Yet
# 7
# 8
# Yet
# Gen
# 11
# Yet
# 13
# 14
# YetGen
# 16
# 17
# Yet
# 19
# Gen
# Yet
# 22
# 23
# Yet
# Gen
# 26
# Yet
# 28
# 29
# YetGen
# 31
# 32
# Yet
# 34
# Gen
# Yet
# 37
# 38
# Yet
# Gen
# 41
# Yet
# 43
# 44
# YetGen
# 46
# 47
# Yet
# 49
# Gen
# Yet
# 52
# 53
# Yet
# Gen
# 56
# Yet
# 58
# 59
# YetGen
# 61
# 62
# Yet
# 64
# Gen
# Yet
# 67
# 68
# Yet
# Gen
# 71
# Yet
# 73
# 74
# YetGen
# 76
# 77
# Yet
# 79
# Gen
# Yet
# 82
# 83
# Yet
# Gen
# 86
# Yet
# 88
# 89
# YetGen
# 91
# 92
# Yet
# 94
# Gen
# Yet
# 97
# 98
# Yet
